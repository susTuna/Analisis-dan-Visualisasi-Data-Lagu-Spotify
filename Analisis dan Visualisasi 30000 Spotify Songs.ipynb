# %% [markdown]
# # **0. Dependencies**

# %% [markdown]
# ## **0.1 Library Installation**

# %%
#install library
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install plotly

# %% [markdown]
# ## **0.2 Import Library dan Membaca Data**

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
#baca data
df=pd.read_csv('spotify_songs.csv') #data yang belum dibersihkan
data=pd.read_csv('spotify_songs_clean_parameter.csv') #data setelah dibersihkan

# %% [markdown]
# # **1. Deskripsi Data**

# %% [markdown]
# ## **1.1 Menampilkan Data**

# %%
#menampilkan data
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %% [markdown]
# ## **1.2 Ukuran Data**

# %%
#menampilkan ukuran data
df.shape
# Out:
# (32833, 23)

# %% [markdown]
# # **2. Karakteristik Data**

# %% [markdown]
# ## **2.1 Atribut Pada Dataset**

# %%
#menampilkan atribut pada dataset dan banyak atribut
columns = df.columns
print(columns)
print(len(columns))
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')
# 23

# %% [markdown]
# ## **2.2 Jenis Atribut Pada Dataset**

# %%
#menampilkan jenis atribut dalam dataset
types = df.dtypes
print(types)
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %% [markdown]
# ## **2.3 Nilai-Nilai dalam Atribut Kategorikal**

# %% [markdown]
# ### **Membuat List Untuk Setiap Tipe Atribut**

# %%
kategorikal = ['track_id','track_name','track_artist','track_album_id','track_album_name','track_album_release_date','playlist_name','playlist_id','playlist_genre','playlist_subgenre','key','mode']
q_kontinu = ['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo']
q_diskrit = ['track_popularity','duration_ms']

# %% [markdown]
# ### **Menampilkan Nilai-Nilai Pada Atribut Kategorikal**

# %%
for i in range(len(kategorikal)):
    print(f'{i+1}.',kategorikal[i])
    variabel = df[kategorikal[i]].value_counts()
    print(variabel)
    print()
#view output as a scrollabel element
# Out:
# 1. track_id
# track_id
# 7BKLCZ1jbUBVqRi2FVlTVw    10
# 14sOS5L36385FJ3OL8hew4     9
# 3eekarcy7kvN4yt5ZFzltW     9
# 2Fxmhks0bxGSBdJ92vM42m     8
# 2tnVG71enUj33Ic2nFN6kZ     8
#                           ..
# 3AKwyujeGxTQSZNbx9Ka3c     1
# 3ITvHA9zhZZdBJsOsAUegF     1
# 5gsW8TMmNVnevjq13h0Nlp     1
# 4pN4icvWINm9uN3bElfbec     1
# 29zWqhca3zt5NsckZqDf6c     1
# Name: count, Length: 28356, dtype: int64
#
# 2. track_name
# track_name
# Poison                    22
# Breathe                   21
# Alive                     20
# Forever                   20
# Stay                      19
#                           ..
# Quien Eres Tu              1
# Como Nadie                 1
# Ya No Estás Aquí           1
# Ojala                      1
# Typhoon - Original Mix     1
# Name: count, Length: 23449, dtype: int64
#
# 3. track_artist
# track_artist
# Martin Garrix       161
# Queen               136
# The Chainsmokers    123
# David Guetta        110
# Don Omar            102
# ...

# %% [markdown]
# ### **Menampilkan Jumlah Nilai Pada Atribut Kategorikal**

# %%
for i in range(len(kategorikal)):
    print(f'{i+1}.',kategorikal[i],end=": ")
    variabel = df[kategorikal[i]].value_counts()
    print(len(variabel))
# Out:
# 1. track_id: 28356
# 2. track_name: 23449
# 3. track_artist: 10692
# 4. track_album_id: 22545
# 5. track_album_name: 19743
# 6. track_album_release_date: 4530
# 7. playlist_name: 449
# 8. playlist_id: 471
# 9. playlist_genre: 6
# 10. playlist_subgenre: 24
# 11. key: 12
# 12. mode: 2

# %% [markdown]
# ## **2.4 Range Nilai Pada Atribut Kuantitatif**

# %% [markdown]
# ### **Menampilkan Range Setiap Atribut Kuantitatif**

# %%
print('atribut kuantitatif kontinu')
for i in range(len(q_kontinu)):
    print(f'{i+1}.',q_kontinu[i],end=": ")
    variabel_max = df[q_kontinu[i]].max()
    variabel_min = df[q_kontinu[i]].min()
    print(variabel_min,'-',variabel_max)
print()
print('atribut kuantitatif diskrit')
for i in range(len(q_diskrit)):
    print(f'{i+1}.',q_diskrit[i],end=": ")
    variabel_max = df[q_diskrit[i]].max()
    variabel_min = df[q_diskrit[i]].min()
    print(variabel_min,'-',variabel_max)
# Out:
# atribut kuantitatif kontinu
# 1. danceability: 0.0 - 0.983
# 2. energy: 0.000175 - 1.0
# 3. loudness: -46.448 - 1.275
# 4. speechiness: 0.0 - 0.918
# 5. acousticness: 0.0 - 0.994
# 6. instrumentalness: 0.0 - 0.994
# 7. liveness: 0.0 - 0.996
# 8. valence: 0.0 - 0.991
# 9. tempo: 0.0 - 239.44
#
# atribut kuantitatif diskrit
# 1. track_popularity: 0 - 100
# 2. duration_ms: 4000 - 517810

# %% [markdown]
# # **3. Statistika**

# %% [markdown]
# # **4. Visualisasi Data**

# %% [markdown]
# ## **4.1 Perbandingan Kategori**

# %% [markdown]
# ### **H-Bar Chart 10 Musisi Dengan Lagu Terbanyak**

# %%
#sorting 10 musisi dengan lagu terbanyak
topartist=data['track_artist'].value_counts().head(10).sort_values(ascending=True)
#array hex code warna
warna=['#9bf6ff','#e7d27c','#d1d1d1','#ffc6ff','#ccb79c','#bdb2ff','#ffadad','#caffbf','#ffd6a5','#a0c4ff']
#visualisasi horizontal bar menggunakan matplotlib
plt.figure(figsize=(8,6))
topartist.plot(kind='barh',xlabel='Jumlah Lagu',ylabel='Nama Musisi',color=warna)
plt.title('Top 10 Musisi Dengan Lagu Terbanyak')
plt.show()

# %% [markdown]
# ### **Danceability by Mode**

# %%
#menampilkan box chart mengenai danceability by mode
#mode 0 adalah Minor dan 1 adalah Mayor
plt.figure(figsize=(10, 6))
sns.boxplot(hue='mode', y='danceability', data=data)
plt.title('Danceability by Mode')
plt.xlabel('Mode')
plt.ylabel('Danceability ')
plt.show()

# %% [markdown]
# ## **4.2 Penampilan Perubahan Terhadap Waktu**

# %% [markdown]
# ### **Line Chart Perilisan Lagu Dari 2015-2019**

# %%
#array bulan
bulan=['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember']
#dictionary untuk menampung data setiap tahun
datax={}
#array tahun
tahun=['2015','2016','2017','2018','2019']
#looping untuk mengisi dictionary
for i in tahun:
    datax[i]=data[data["track_album_release_date"].str.contains(i)]["track_album_release_date"].str.slice(5,7).value_counts().sort_index()
#membuat dataframe dari dictionary
monthDat=pd.DataFrame(datax)
#array
warna3=['red','orange','yellow','green','blue']
monthDat.plot(kind='line',y=tahun, figsize=(15,7), legend=True, color=warna3)
plt.title('Jumlah Lagu yang Dirilis Dari 2015-2019')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Lagu')
plt.xticks([i for i in range(1,13)],bulan)
plt.show()

# %% [markdown]
# ### **Line Chart Jumlah Lagu Pada Bulan November 2019**

# %%
#filtrasi lagu yang hanya dirilis pada November 2019
dataz=data[data["track_album_release_date"].str.contains("2019-11")]
#membuat data frame untuk memuat hari dan nama lagu dan membuat visualisasinya
dz=pd.DataFrame({
    "day": dataz["track_album_release_date"].str.slice(8,10).astype(int),
    "name": dataz["track_name"]
}).groupby("day").size().plot(kind="line", figsize=(15,7), color='blue', legend=True, label='November 2019')
plt.title('Jumlah Lagu yang Dirilis per Hari pada Bulan November 2019')
plt.xlabel('Hari ke-')
plt.ylabel('Jumlah Lagu')
plt.xticks(range(1,31))
plt.show()

# %% [markdown]
# ## **4.3 Penampilan Hirarki dan Hubungan Keseluruhan Bagian**

# %% [markdown]
# ### **Diagram Pie Distribusi Genre Lagu**

# %%
#menghitung jumlah lagu tiap genre
genre=data['playlist_genre'].value_counts()
#array hex code warna
warna2=['#ffadad','#ffd6a5','#fdffb6','#caffbf','#a0c4ff','#bdb2ff']
#visualisasi pie chart menggunakan matplotlib
plt.figure(figsize=[8,8])
genre.plot(kind='pie',title='Distribusi Genre Lagu',ylabel='Frekuensi',colors=warna2,autopct='%1.1f%%', legend=True)
plt.show()

# %% [markdown]
# ### **Treemap Popularitas dengan Genre**

# %%
datak={} #dictionary untuk menampung data
datak['track_popularity']=[] #menampung nilai rate
datak['count']=[] #menampung nilai popularity per genre
datak['playlist_genre']=[] #menampung genre
#array jangkauan rating dan genre
rate=[i for i in range(0,101,10)]
genre=['rap','edm','rock','latin','r&b','pop']
k=0 #j sebelumnya = 0 karena belum ada j
#nested loop untuk mengisi dictionary
for m in genre:
    for i in rate:
        j=len(data[(data["track_popularity"]<=int(i))&(data["playlist_genre"]==m)])
        datak['track_popularity'].append(i)
        datak['count'].append(j-k) #j dikurang j sebelumnya
        datak['playlist_genre'].append(m)
        k=j #k menjadi j sebelumnya
    k=0 #reset counter k  
#membuat dataframe dari dictionary
datao=pd.DataFrame(datak)

# %%
#visualisasi tree map menggunakan plotly
fig=px.treemap(datao,path=['playlist_genre','track_popularity'],values='count')
fig.show()

# %% [markdown]
# ## **4.4 Plotting Relationships**

# %% [markdown]
# ### **Scatter Plot Hubungan Antara Popularitas Lagu dengan Durasi Lagu**

# %%
#menampilkan hubungan antara popularitas lagu dengan durasinya
korel=data['track_popularity'].corr(data['duration_ms'])
data.plot(kind='scatter',x='track_popularity',y='duration_ms',figsize=[15,7],legend=True,label=f'Correlation: {korel}')
plt.title('Hubungan antara Popularitas Lagu dengan Durasi Lagu')
plt.show()

# %% [markdown]
# ### **Bubble Plot Hubungan Antara Energy dan Valence Dari Mode Lagu**

# %%
#menampilkan hubungan antara energy dan valence dari lagu dengan mengelompokkan lagu berdasarkan mode
#lagu yang dipilih adalah lagu yang berada pada top 20%
#mode 0 adalah Minor dan 1 adalah Mayor
plt.figure(figsize=(10, 6))
sns.scatterplot(x='energy', y='valence', size='track_popularity', hue='mode', edgecolors="black",data=data[data['track_popularity']>=80],alpha=0.5,sizes=(20, 400))
plt.title('Hubungan Antara Energy dan Valence')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=17)
plt.xlabel('Energy')
plt.ylabel('Valence')
plt.show()

# %% [markdown]
# # **5. Korelasi**

# %% [markdown]
# ### **Heatmap Korelasi Semua Variabel Angka**

# %%
korelasi=data.select_dtypes(include=['int64','float64']).corr()
plt.figure(figsize=(10,10))
plt.imshow(korelasi,cmap='coolwarm',vmin=-1,vmax=1)
for i in range(len(korelasi)):
    for j in range(len(korelasi)):
        plt.annotate(str(round(korelasi.values[i][j], 3)),\
                     xy=(j+0.01, i+0.01),
                     ha='center', va='center', color='black')
plt.colorbar(ticks=[-1,0,1]).ax.set_yticklabels(['Berbanding Terbalik','Tidak Berkorelasi','Berbanding Lurus'])
plt.title('Heatmap Korelasi')
plt.xticks(range(len(korelasi.columns)),\
           korelasi.columns, rotation=90)
plt.yticks(range(len(korelasi.columns)),
           korelasi.columns)
plt.show()

# %% [markdown]
# # **6. Data Cleansing**

# %% [markdown]
# ## **6.1 Data Kosong**

# %% [markdown]
# ### **Menampilkan Data Kosong**

# %%
# Mencari data yang kosong
df.loc[df.isna().any(axis=1)]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# ...

# %% [markdown]
# ### **Menghilangkan Data Kosong**

# %%
# Menghilangkan data kosong
dx = df.dropna()

# Membuat output data setelah menghilangkan data kosong
dx
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %% [markdown]
# ### **Memastikan File Adalah Dataset**

# %%
# Memastikan data masih berupa dataset
if isinstance(data, pd.DataFrame):
    # Menyimpan dataset bersih sesuai parameter ke dalam file baru
    dx.to_csv('spotify_songs_clean.csv', index=False)
else:
    print("Variabel data bukanlah dataframe, terdapat kesalahan pada cleansing process.")

# %% [markdown]
# ## **6.2 Anomali Data**

# %% [markdown]
# ### **Membuat List Untuk Tipe Data**

# %%
#deskripsi kelas-kelas kolom data
data_cl = pd.read_csv('spotify_songs_clean.csv')
kategorikal = ['track_id','track_name','track_artist','track_album_id','track_album_name','track_album_release_date','playlist_name','playlist_id','playlist_genre','playlist_subgenre','key','mode']
q_kontinu = ['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo']
q_diskrit = ['track_popularity','duration_ms']

# %% [markdown]
# ### **Mencari Range dari Data yang Bersifat Kuantitatif**

# %%
print('atribut kuantitatif kontinu')

# mencari range dari data kuantitatif kontinu
for i in range(len(q_kontinu)):
    # output nama kolom
    print(f'{i+1}.',q_kontinu[i],end=": ")
    # membuat range max dan min data
    variabel_max = data_cl[q_kontinu[i]].max()
    variabel_min = data_cl[q_kontinu[i]].min()
    # output range data
    print(variabel_min,'-',variabel_max)

print()     # membuat jeda
# mencari range dari data kuantitatif diskrit
print('atribut kuantitatif diskrit')
for i in range(len(q_diskrit)):
    # output nama kolom
    print(f'{i+1}.',q_diskrit[i],end=": ")
    # membuat range max dan min data
    variabel_max = data_cl[q_diskrit[i]].max()
    variabel_min = data_cl[q_diskrit[i]].min()
    # output range data
    print(variabel_min,'-',variabel_max)
# Out:
# atribut kuantitatif kontinu
# 1. danceability: 0.0 - 0.983
# 2. energy: 0.000175 - 1.0
# 3. loudness: -46.448 - 1.275
# 4. speechiness: 0.0 - 0.918
# 5. acousticness: 0.0 - 0.994
# 6. instrumentalness: 0.0 - 0.994
# 7. liveness: 0.0 - 0.996
# 8. valence: 0.0 - 0.991
# 9. tempo: 0.0 - 239.44
#
# atribut kuantitatif diskrit
# 1. track_popularity: 0 - 100
# 2. duration_ms: 4000 - 517810

# %% [markdown]
# ### **Mencari Data yang Berada di Luar Range**

# %%
# Menentukan rentang seharusnya
expected_range = (-60, 0)

# Filter data yang berada di luar rentang
out_of_range_data = data_cl[(data_cl['loudness'] < expected_range[0]) | (data_cl['loudness'] > expected_range[1])]

# Menampilkan data yang berada di luar rentang
print("Data yang berada di luar rentang:")
out_of_range_data
# Out:
# Data yang berada di luar rentang:
#                      track_id                      track_name track_artist  \
# 9880   0jsbEBnXWgHLkvjV49vYVG                           Nails   Ghostemane
# 10435  02fPJUlHDeH46EB1dHrgmZ                           Crema         Owin
# 10455  5DQGkXXLiOhf5cKqIyWh5L                        Rockstar         Duki
# 12194  3BnVqaDfgKyI4CFCfozors        Raw Power - Iggy Pop Mix  The Stooges
# 27711  6TaqE6fbzfOGTSnNqmsAMO  Escape From Love - Curbi Remix   Eva Simons
# 30334  2kOmW169C7UV4SZDN9u0YO                 Vidrado Em Você     Dj Guuga
#
#        track_popularity          track_album_id  \
# 9880                 49  6DIKWvXlVjvAx1JngSuSx9
# 10435                43  281103RQ7mvsWEDvJHik6s
# 10455                 2  1F7NrR7X4rxJflXq1mCLOC
# 12194                36  6mxbG8KrOTZIxlP4gzaliM
# 27711                 0  51Tg4iZyqpqp1dZD4GRfb8
# 30334                78  5HebljJgeo97MOazTC2xPV
#
# ...

# %% [markdown]
# ### **Menghilangkan Data yang Berada di Luar Range**

# %%
# Menghilangkan data yang berada di luar rentang
data_cl = data_cl[(data_cl['loudness'] >= expected_range[0]) & (data_cl['loudness'] <= expected_range[1])]

# Menampilkan data setelah menghilangkan data yang berada di luar rentang
print("\nData setelah menghilangkan data yang berada di luar rentang:")
data_cl
# Out:
# Data setelah menghilangkan data yang berada di luar rentang:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32823  7bxnKAamR3snQ1VGLuVfC1
# 32824  5Aevni09Em4575077nkWHz
# 32825  7ImMqPP3Q1yfUHvsdn7wEo
# 32826  2m69mhnfQ1Oq6lGtXuYhgX
# 32827  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %% [markdown]
# ### **Menampilkan Ukuran Data Baru**

# %%
# membuat ukuran data baru
data_cl.shape
# Out:
# (32822, 23)

# %% [markdown]
# ### **Memastikan Data Masih Berupa Dataset**

# %%
#Memastikan data masih berupa dataset
if isinstance(data_cl, pd.DataFrame):
    # Menyimpan dataset bersih sesuai parameter ke dalam file baru
    data_cl.to_csv('spotify_songs_clean_parameter.csv', index=False)
else:
    print("Variabel data bukanlah dataframe, terdapat kesalahan pada cleansing process.")

# %% [markdown]
# ### **Membaca Data yang Sudah Bersih**

# %%
# mendefinisikan data baru yang berasal dari file terbaru
data = pd.read_csv('spotify_songs_clean_parameter.csv')

# %% [markdown]
# ### **Menampilkan Range Data yang Sudah Bersih**

# %%
#menampilkan range data yang sudah bersih
print('atribut kuantitatif kontinu')

# mencari range dari data kuantitatif kontinu
for i in range(len(q_kontinu)):
    # output nama kolom
    print(f'{i+1}.',q_kontinu[i],end=": ")
    # membuat range max dan min data
    variabel_max = df[q_kontinu[i]].max()
    variabel_min = df[q_kontinu[i]].min()
    # output range data
    print(variabel_min,'-',variabel_max)
# Out:
# atribut kuantitatif kontinu
# 1. danceability: 0.0 - 0.983
# 2. energy: 0.000175 - 1.0
# 3. loudness: -46.448 - 1.275
# 4. speechiness: 0.0 - 0.918
# 5. acousticness: 0.0 - 0.994
# 6. instrumentalness: 0.0 - 0.994
# 7. liveness: 0.0 - 0.996
# 8. valence: 0.0 - 0.991
# 9. tempo: 0.0 - 239.44
